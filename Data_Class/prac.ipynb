# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/Users/andrewbadzioch/Desktop/MLB_stuff/data/pitcherStat2024.csv')

# %%
pitch = df.copy()
pitch.head()
# Out:
#   last_name, first_name  player_id  year  player_age  p_game  p_formatted_ip  \
# 0          Fedde, Erick     607200  2024          31      31           177.1
# 1      Taillon, Jameson     592791  2024          32      28           165.1
# 2          López, Pablo     641154  2024          28      32           185.1
# 3           Eflin, Zach     621107  2024          30      28           165.1
# 4         Houck, Tanner     656557  2024          28      30           178.2
#
#     pa   ab  hit  single  ...  blasts_contact  blasts_swing  \
# 0  726  661  154     100  ...            13.4          10.6
# 1  675  633  154     107  ...            15.8          13.1
# 2  772  715  180     121  ...            11.5           8.6
# 3  684  653  166     114  ...            15.4          12.4
# 4  743  674  156     118  ...            16.0          12.6
#
#    squared_up_contact  squared_up_swing  avg_swing_length  swords  \
# 0                33.4              26.5               7.2      15
# ...

# %%
print("the shape of the dataset is: ", pitch.shape, '\n')
print("the size of the dataset is: ", pitch.size, '\n')
print("the columns of the dataset are: ", pitch.columns, '\n')
# Out:
# the shape of the dataset is:  (107, 39)
#
# the size of the dataset is:  4173
#
# the columns of the dataset are:  Index(['last_name, first_name', 'player_id', 'year', 'player_age', 'p_game',
#        'p_formatted_ip', 'pa', 'ab', 'hit', 'single', 'double', 'triple',
#        'home_run', 'strikeout', 'walk', 'k_percent', 'bb_percent',
#        'batting_avg', 'slg_percent', 'on_base_percent', 'on_base_plus_slg',
#        'xba', 'xslg', 'woba', 'xwoba', 'xobp', 'xiso', 'avg_swing_speed',
#        'fast_swing_rate', 'blasts_contact', 'blasts_swing',
#        'squared_up_contact', 'squared_up_swing', 'avg_swing_length', 'swords',
#        'exit_velocity_avg', 'launch_angle_avg', 'sweet_spot_percent',
#        'barrel_batted_rate'],
#       dtype='object')

# %%
pitch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   last_name, first_name  107 non-null    object
#  1   player_id              107 non-null    int64
#  2   year                   107 non-null    int64
#  3   player_age             107 non-null    int64
#  4   p_game                 107 non-null    int64
#  5   p_formatted_ip         107 non-null    float64
#  6   pa                     107 non-null    int64
#  7   ab                     107 non-null    int64
#  8   hit                    107 non-null    int64
#  9   single                 107 non-null    int64
#  10  double                 107 non-null    int64
#  11  triple                 107 non-null    int64
#  12  home_run               107 non-null    int64
#  13  strikeout              107 non-null    int64
#  14  walk                   107 non-null    int64
# ...

# %%
pitch.describe()
# Out:
#            player_id    year  player_age      p_game  p_formatted_ip  \
# count     107.000000   107.0  107.000000  107.000000      107.000000
# mean   632635.616822  2024.0   28.869159   29.420561      160.127103
# std     53513.052138     0.0    3.731771    3.370341       22.603104
# min    450203.000000  2024.0   22.000000   21.000000      117.000000
# 25%    607070.500000  2024.0   26.000000   28.000000      141.100000
# 50%    656427.000000  2024.0   28.000000   30.000000      165.100000
# 75%    669449.500000  2024.0   31.500000   32.000000      177.150000
# max    694973.000000  2024.0   40.000000   42.000000      208.200000
#
#                pa          ab         hit      single      double  ...  \
# count  107.000000  107.000000  107.000000  107.000000  107.000000  ...
# mean   667.859813  608.177570  146.401869   94.560748   29.140187  ...
# std     88.539987   84.582751   24.793814   19.175543    7.044935  ...
# ...

# %%
pitch.isnull().sum()
# Out:
# last_name, first_name    0
# player_id                0
# year                     0
# player_age               0
# p_game                   0
# p_formatted_ip           0
# pa                       0
# ab                       0
# hit                      0
# single                   0
# double                   0
# triple                   0
# home_run                 0
# strikeout                0
# walk                     0
# k_percent                0
# bb_percent               0
# batting_avg              0
# slg_percent              0
# on_base_percent          0
# on_base_plus_slg         0
# xba                      0
# xslg                     0
# woba                     0
# xwoba                    0
# xobp                     0
# xiso                     0
# avg_swing_speed          0
# fast_swing_rate          0
# blasts_contact           0
# blasts_swing             0
# squared_up_contact       0
# squared_up_swing         0
# avg_swing_length         0
# ...
