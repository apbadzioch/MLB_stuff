# %% [markdown]
# # Practice Data Analysis of the 2024 MLB season
# - data from https://www.retrosheet.org/schedule/index.html
#     - The information used here was obtained free of
#       charge from and is copyrighted by Retrosheet.
#       Interested parties may contact Retrosheet at
#       20 Sunset Rd., Newark, DE 19711.

# %% [markdown]
# ### Data Description: Field(s)   Meaning
# 1. Date in the form "yyyymmdd"
# 2. Number of game:
#     - "0" - a single game
#     - "1" - the first game of a double header including separate admission doubleheaders
#     - "2" - the second game of a double header including separate admission doubleheaders
# 3. day of week ("Sun","Mon","Tue","Wed","Thur","Fri","Sat")
# 4. visiting team
# 5. visiting team league
# 6. season game number for visiting team
# 7. home team
# 8. home team league
# 9. season game number for home team
# 10. day (D), night (N), afternoon (A), evening (E for twinight)
# 11. location
# 12. postponement/cancellation indicator
# 13. date of makeup if played in the form "yyyymmdd"

# %%
# pip install pybaseball

# %%
import pybaseball as pyball
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('2024schedule.csv')

# %%
mlb = df.copy()
mlb.head()
# Out:
#        Date  Num        Day Visitor League  Game Home League.1  Game.1  \
# 0  20240320    0  Wednesday     LAN     NL     1  SDN       NL       1
# 1  20240321    0   Thursday     SDN     NL     2  LAN       NL       2
# 2  20240328    0   Thursday     MIL     NL     1  NYN       NL       1
# 3  20240328    0   Thursday     ANA     AL     1  BAL       AL       1
# 4  20240328    0   Thursday     ATL     NL     1  PHI       NL       1
#
#   Day/Night Location  Postponed  Makeup
# 0         n    SEO01        NaN     NaN
# 1         n    SEO01        NaN     NaN
# 2         d    NYC20        NaN     NaN
# 3         d    BAL12        NaN     NaN
# 4         d    PHI13        NaN     NaN

# %%
mlb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2430 entries, 0 to 2429
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2430 non-null   int64
#  1   Num        2430 non-null   int64
#  2   Day        2430 non-null   object
#  3   Visitor    2430 non-null   object
#  4   League     2430 non-null   object
#  5   Game       2430 non-null   int64
#  6   Home       2430 non-null   object
#  7   League.1   2430 non-null   object
#  8   Game.1     2430 non-null   int64
#  9   Day/Night  2430 non-null   object
#  10  Location   2430 non-null   object
#  11  Postponed  0 non-null      float64
#  12  Makeup     0 non-null      float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 246.9+ KB

# %% [markdown]
# **Working with Attributes**
# - shape
# - size
# - columns
# - dtypes
# - ndim

# %%
mlb.shape
# Out:
# (2430, 13)

# %%
mlb.size
# Out:
# 31590

# %%
mlb.columns
# Out:
# Index(['Date', 'Num', 'Day', 'Visitor', 'League', 'Game', 'Home', 'League.1',
#        'Game.1', 'Day/Night', 'Location', 'Postponed', 'Makeup'],
#       dtype='object')

# %%
mlb.dtypes
# Out:
# Date           int64
# Num            int64
# Day           object
# Visitor       object
# League        object
# Game           int64
# Home          object
# League.1      object
# Game.1         int64
# Day/Night     object
# Location      object
# Postponed    float64
# Makeup       float64
# dtype: object

# %%
mlb.ndim
# Out:
# 2

# %%
# index location: .iloc[]
# remember that the index location will vary slightly from actual location
mlb.iloc[455]
# Out:
# Date         20240430
# Num                 0
# Day           Tuesday
# Visitor           ATL
# League             NL
# Game               30
# Home              SEA
# League.1           AL
# Game.1             30
# Day/Night           n
# Location        SEA03
# Postponed         NaN
# Makeup            NaN
# Name: 455, dtype: object

# %%
# finding the total number of games played at each stadium using a Series
# total regular season games played = 162
mlb['Location'].value_counts()
# Out:
# Location
# WAS11    81
# OAK01    81
# CLE08    81
# TOR02    81
# ANA01    81
# ATL03    81
# SFO03    81
# PIT08    81
# NYC21    81
# MIN04    81
# MIL06    81
# CHI11    81
# PHO01    81
# SEA03    81
# ARL03    81
# MIA02    81
# BAL12    81
# CHI12    81
# CIN09    81
# HOU03    81
# KAN06    81
# BOS07    81
# STP01    81
# STL10    80
# SAN02    80
# NYC20    80
# PHI13    80
# LOS03    80
# DET05    80
# DEN02    79
# LON01     2
# SEO01     2
# MEX02     2
# BIR01     1
# WIL02     1
# Name: count, dtype: int64

# %%
# finding specific things about a certain thing
mlb.value_counts([mlb['Location'] == 'LOS03'])
# Out:
# Location
# False       2350
# True          80
# Name: count, dtype: int64

# %%
# filtering within a Series
mlb[mlb['Location'] == 'LOS03']
# Out:
#           Date  Num        Day Visitor League  Game Home League.1  Game.1  \
# 12    20240328    0   Thursday     SLN     NL     1  LAN       NL       3
# 24    20240329    0     Friday     SLN     NL     2  LAN       NL       4
# 38    20240330    0   Saturday     SLN     NL     3  LAN       NL       5
# 54    20240331    0     Sunday     SLN     NL     4  LAN       NL       6
# 68    20240401    0     Monday     SFN     NL     5  LAN       NL       7
# ...        ...  ...        ...     ...    ...   ...  ...      ...     ...
# 2326  20240921    0   Saturday     COL     NL   155  LAN       NL     155
# 2341  20240922    0     Sunday     COL     NL   156  LAN       NL     156
# 2360  20240924    0    Tuesday     SDN     NL   157  LAN       NL     157
# 2375  20240925    0  Wednesday     SDN     NL   158  LAN       NL     158
# 2384  20240926    0   Thursday     SDN     NL   159  LAN       NL     159
#
#      Day/Night Location  Postponed  Makeup
# 12           d    LOS03        NaN     NaN
# 24           n    LOS03        NaN     NaN
# 38           n    LOS03        NaN     NaN
# 54           d    LOS03        NaN     NaN
# 68           n    LOS03        NaN     NaN
# ...        ...      ...        ...     ...
# 2326         n    LOS03        NaN     NaN
# 2341         d    LOS03        NaN     NaN
# 2360         n    LOS03        NaN     NaN
# 2375         n    LOS03        NaN     NaN
# 2384         n    LOS03        NaN     NaN
#
# [80 rows x 13 columns]

# %%
mlb.value_counts([mlb['Location'] == 'HOU03'])
# Out:
# Location
# False       2349
# True          81
# Name: count, dtype: int64

# %%
mlb[mlb['Location'] == 'HOU03']
# Out:
#           Date  Num        Day Visitor League  Game Home League.1  Game.1  \
# 7     20240328    0   Thursday     NYA     AL     1  HOU       AL       1
# 19    20240329    0     Friday     NYA     AL     2  HOU       AL       2
# 35    20240330    0   Saturday     NYA     AL     3  HOU       AL       3
# 47    20240331    0     Sunday     NYA     AL     4  HOU       AL       4
# 63    20240401    0     Monday     TOR     AL     5  HOU       AL       5
# ...        ...  ...        ...     ...    ...   ...  ...      ...     ...
# 2320  20240921    0   Saturday     ANA     AL   155  HOU       AL     155
# 2333  20240922    0     Sunday     ANA     AL   156  HOU       AL     156
# 2344  20240923    0     Monday     SEA     AL   157  HOU       AL     157
# 2356  20240924    0    Tuesday     SEA     AL   158  HOU       AL     158
# 2361  20240925    0  Wednesday     SEA     AL   159  HOU       AL     159
#
#      Day/Night Location  Postponed  Makeup
# 7            d    HOU03        NaN     NaN
# 19           n    HOU03        NaN     NaN
# 35           n    HOU03        NaN     NaN
# 47           d    HOU03        NaN     NaN
# 63           n    HOU03        NaN     NaN
# ...        ...      ...        ...     ...
# 2320         n    HOU03        NaN     NaN
# 2333         d    HOU03        NaN     NaN
# 2344         n    HOU03        NaN     NaN
# 2356         n    HOU03        NaN     NaN
# 2361         d    HOU03        NaN     NaN
#
# [81 rows x 13 columns]

# %%
mlb[mlb['Location'] == 'SEO01']
# Out:
#        Date  Num        Day Visitor League  Game Home League.1  Game.1  \
# 0  20240320    0  Wednesday     LAN     NL     1  SDN       NL       1
# 1  20240321    0   Thursday     SDN     NL     2  LAN       NL       2
#
#   Day/Night Location  Postponed  Makeup
# 0         n    SEO01        NaN     NaN
# 1         n    SEO01        NaN     NaN

# %%
mlb[mlb['Location'] == 'MEX02']
# Out:
#          Date  Num       Day Visitor League  Game Home League.1  Game.1  \
# 405  20240427    0  Saturday     HOU     AL    27  COL       NL      27
# 423  20240428    0    Sunday     HOU     AL    28  COL       NL      28
#
#     Day/Night Location  Postponed  Makeup
# 405         d    MEX02        NaN     NaN
# 423         d    MEX02        NaN     NaN

# %%
df1 = pd.read_csv('batterStat2024.csv')
df1.head()
# Out:
#     last_name, first_name  player_id  year  player_age   ab   pa  hit  single  \
# 0  Guerrero Jr., Vladimir     665489  2024          25  616  697  199     124
# 1           Ramírez, José     608070  2024          31  620  682  173      93
# 2           Hoskins, Rhys     656555  2024          31  449  517   96      56
# 3             Gelof, Zack     680869  2024          24  497  547  105      66
# 4         Varsho, Daulton     662139  2024          27  459  513   98      52
#
#    double  triple  ...  blasts_contact  blasts_swing  squared_up_contact  \
# 0      44       1  ...            24.2          19.4                34.5
# 1      39       2  ...            13.9          12.1                32.6
# 2      14       0  ...            12.0           9.1                29.8
# 3      20       2  ...            12.0           7.8                30.4
# 4      21       7  ...            11.1           8.2                24.0
#
#    squared_up_swing  avg_swing_length  swords  exit_velocity_avg  \
# 0              27.7               7.7       9               93.8
# 1              28.3               7.3      17               89.2
# 2              22.8               8.1      23               88.7
# 3              19.8               7.3      23               89.2
# 4              17.7               7.6       6               86.1
#
#    launch_angle_avg  sweet_spot_percent  barrel_batted_rate
# 0               7.4                35.1                13.7
# 1              19.6                34.0                 8.6
# 2              20.8                29.7                12.7
# 3              14.2                34.4                 8.8
# 4              24.4                30.2                 6.2
#
# [5 rows x 37 columns]

# %%
stats = df1.copy()

# %%
stats.set_index('last_name, first_name', inplace=True)
stats.head()
# Out:
#                         player_id  year  player_age   ab   pa  hit  single  \
# last_name, first_name
# Guerrero Jr., Vladimir     665489  2024          25  616  697  199     124
# Ramírez, José              608070  2024          31  620  682  173      93
# Hoskins, Rhys              656555  2024          31  449  517   96      56
# Gelof, Zack                680869  2024          24  497  547  105      66
# Varsho, Daulton            662139  2024          27  459  513   98      52
#
#                         double  triple  home_run  ...  blasts_contact  \
# last_name, first_name                             ...
# Guerrero Jr., Vladimir      44       1        30  ...            24.2
# Ramírez, José               39       2        39  ...            13.9
# Hoskins, Rhys               14       0        26  ...            12.0
# Gelof, Zack                 20       2        17  ...            12.0
# Varsho, Daulton             21       7        18  ...            11.1
#
#                         blasts_swing  squared_up_contact  squared_up_swing  \
# last_name, first_name
# Guerrero Jr., Vladimir          19.4                34.5              27.7
# Ramírez, José                   12.1                32.6              28.3
# Hoskins, Rhys                    9.1                29.8              22.8
# Gelof, Zack                      7.8                30.4              19.8
# Varsho, Daulton                  8.2                24.0              17.7
#
#                         avg_swing_length  swords  exit_velocity_avg  \
# last_name, first_name
# Guerrero Jr., Vladimir               7.7       9               93.8
# Ramírez, José                        7.3      17               89.2
# Hoskins, Rhys                        8.1      23               88.7
# Gelof, Zack                          7.3      23               89.2
# Varsho, Daulton                      7.6       6               86.1
#
#                         launch_angle_avg  sweet_spot_percent  \
# last_name, first_name
# Guerrero Jr., Vladimir               7.4                35.1
# Ramírez, José                       19.6                34.0
# Hoskins, Rhys                       20.8                29.7
# Gelof, Zack                         14.2                34.4
# Varsho, Daulton                     24.4                30.2
#
#                         barrel_batted_rate
# last_name, first_name
# Guerrero Jr., Vladimir                13.7
# Ramírez, José                          8.6
# Hoskins, Rhys                         12.7
# Gelof, Zack                            8.8
# Varsho, Daulton                        6.2
#
# [5 rows x 36 columns]

# %%
stats.shape
# Out:
# (129, 36)

# %%
stats.iloc[58]
# Out:
# player_id             691026.000
# year                    2024.000
# player_age                22.000
# ab                       587.000
# pa                       637.000
# hit                      157.000
# single                   105.000
# double                    32.000
# triple                     5.000
# home_run                  15.000
# strikeout                109.000
# walk                      41.000
# k_percent                 17.100
# bb_percent                 6.400
# batting_avg                0.267
# slg_percent                0.416
# on_base_percent            0.314
# on_base_plus_slg           0.730
# xba                        0.259
# xslg                       0.366
# woba                       0.315
# xwoba                      0.296
# xobp                       0.308
# xiso                       0.107
# avg_swing_speed           70.200
# fast_swing_rate           11.500
# blasts_contact            12.000
# blasts_swing               9.900
# squared_up_contact        32.200
# squared_up_swing          26.500
# avg_swing_length           7.300
# swords                    14.000
# exit_velocity_avg         87.000
# launch_angle_avg          13.200
# sweet_spot_percent        33.500
# barrel_batted_rate         3.700
# Name: Winn, Masyn, dtype: float64

# %%
stats.loc['Bregman, Alex']
# Out:
# player_id             608324.000
# year                    2024.000
# player_age                30.000
# ab                       581.000
# pa                       634.000
# hit                      151.000
# single                    93.000
# double                    30.000
# triple                     2.000
# home_run                  26.000
# strikeout                 86.000
# walk                      44.000
# k_percent                 13.600
# bb_percent                 6.900
# batting_avg                0.260
# slg_percent                0.453
# on_base_percent            0.315
# on_base_plus_slg           0.768
# xba                        0.262
# xslg                       0.428
# woba                       0.331
# xwoba                      0.323
# xobp                       0.318
# xiso                       0.167
# avg_swing_speed           71.400
# fast_swing_rate           11.800
# blasts_contact            13.300
# blasts_swing              11.900
# squared_up_contact        37.900
# squared_up_swing          33.800
# avg_swing_length           7.000
# swords                     7.000
# exit_velocity_avg         89.100
# launch_angle_avg          18.200
# sweet_spot_percent        34.900
# barrel_batted_rate         6.400
# Name: Bregman, Alex, dtype: float64

# %%
stats.sort_values('home_run', ascending=False)
# Out:
#                        player_id  year  player_age   ab   pa  hit  single  \
# last_name, first_name
# Judge, Aaron              592450  2024          32  559  704  180      85
# Ohtani, Shohei            660271  2024          29  636  731  197      98
# Santander, Anthony        623993  2024          29  595  665  140      69
# Soto, Juan                665742  2024          25  576  713  166      90
# Ramírez, José             608070  2024          31  620  682  173      93
# ...                          ...   ...         ...  ...  ...  ...     ...
# Turang, Brice             668930  2024          24  559  619  142     107
# Hoerner, Nico             663538  2024          27  582  641  159     116
# Arraez, Luis              650333  2024          27  637  672  200     161
# Young, Jacob              696285  2024          24  468  521  120      92
# Frelick, Sal              686217  2024          24  475  524  123      95
#
#                        double  triple  home_run  ...  blasts_contact  \
# last_name, first_name                            ...
# Judge, Aaron               36       1        58  ...            25.4
# Ohtani, Shohei             38       7        54  ...            25.4
# Santander, Anthony         25       2        44  ...            13.7
# Soto, Juan                 31       4        41  ...            25.9
# Ramírez, José              39       2        39  ...            13.9
# ...                       ...     ...       ...  ...             ...
# Turang, Brice              24       4         7  ...             6.2
# Hoerner, Nico              35       1         7  ...             7.2
# Arraez, Luis               32       3         4  ...             4.9
# Young, Jacob               24       1         3  ...             8.9
# Frelick, Sal               22       4         2  ...             6.0
#
#                        blasts_swing  squared_up_contact  squared_up_swing  \
# last_name, first_name
# Judge, Aaron                   17.9                33.5              23.6
# Ohtani, Shohei                 17.9                37.5              26.4
# Santander, Anthony             11.0                27.6              22.3
# Soto, Juan                     21.0                39.7              32.1
# Ramírez, José                  12.1                32.6              28.3
# ...                             ...                 ...               ...
# Turang, Brice                   5.4                33.8              29.2
# Hoerner, Nico                   6.4                35.4              31.7
# Arraez, Luis                    4.6                46.5              43.9
# Young, Jacob                    7.4                35.7              29.4
# Frelick, Sal                    5.3                36.1              31.7
#
#                        avg_swing_length  swords  exit_velocity_avg  \
# last_name, first_name
# Judge, Aaron                        8.2      16               96.2
# Ohtani, Shohei                      7.8      10               95.8
# Santander, Anthony                  7.2       7               89.8
# Soto, Juan                          7.3      30               94.2
# Ramírez, José                       7.3      17               89.2
# ...                                 ...     ...                ...
# Turang, Brice                       6.1      12               87.0
# Hoerner, Nico                       7.1      11               85.7
# Arraez, Luis                        6.0       8               86.3
# Young, Jacob                        6.9      20               85.8
# Frelick, Sal                        6.9      10               83.4
#
#                        launch_angle_avg  sweet_spot_percent  \
# last_name, first_name
# Judge, Aaron                       19.0                40.8
# Ohtani, Shohei                     16.2                37.8
# Santander, Anthony                 22.7                35.0
# Soto, Juan                         10.7                35.4
# Ramírez, José                      19.6                34.0
# ...                                 ...                 ...
# Turang, Brice                       6.1                32.0
# Hoerner, Nico                      10.4                36.0
# Arraez, Luis                       13.7                40.9
# Young, Jacob                        4.0                28.1
# Frelick, Sal                        9.7                30.0
#
#                        barrel_batted_rate
# last_name, first_name
# Judge, Aaron                         26.9
# Ohtani, Shohei                       21.5
# Santander, Anthony                   11.7
# Soto, Juan                           19.7
# Ramírez, José                         8.6
# ...                                   ...
# Turang, Brice                         2.4
# Hoerner, Nico                         1.2
# Arraez, Luis                          1.6
# Young, Jacob                          1.6
# Frelick, Sal                          0.8
#
# [129 rows x 36 columns]

# %%
stats.loc['Ohtani, Shohei']
# Out:
# player_id             660271.000
# year                    2024.000
# player_age                29.000
# ab                       636.000
# pa                       731.000
# hit                      197.000
# single                    98.000
# double                    38.000
# triple                     7.000
# home_run                  54.000
# strikeout                162.000
# walk                      81.000
# k_percent                 22.200
# bb_percent                11.100
# batting_avg                0.310
# slg_percent                0.646
# on_base_percent            0.390
# on_base_plus_slg           1.036
# xba                        0.320
# xslg                       0.678
# woba                       0.431
# xwoba                      0.448
# xobp                       0.401
# xiso                       0.358
# avg_swing_speed           76.300
# fast_swing_rate           64.200
# blasts_contact            25.400
# blasts_swing              17.900
# squared_up_contact        37.500
# squared_up_swing          26.400
# avg_swing_length           7.800
# swords                    10.000
# exit_velocity_avg         95.800
# launch_angle_avg          16.200
# sweet_spot_percent        37.800
# barrel_batted_rate        21.500
# Name: Ohtani, Shohei, dtype: float64

# %%
stats.dtypes
# Out:
# player_id               int64
# year                    int64
# player_age              int64
# ab                      int64
# pa                      int64
# hit                     int64
# single                  int64
# double                  int64
# triple                  int64
# home_run                int64
# strikeout               int64
# walk                    int64
# k_percent             float64
# bb_percent            float64
# batting_avg           float64
# slg_percent           float64
# on_base_percent       float64
# on_base_plus_slg      float64
# xba                   float64
# xslg                  float64
# woba                  float64
# xwoba                 float64
# xobp                  float64
# xiso                  float64
# avg_swing_speed       float64
# fast_swing_rate       float64
# blasts_contact        float64
# blasts_swing          float64
# squared_up_contact    float64
# squared_up_swing      float64
# avg_swing_length      float64
# swords                  int64
# exit_velocity_avg     float64
# launch_angle_avg      float64
# sweet_spot_percent    float64
# barrel_batted_rate    float64
# dtype: object

# %%
stats1 = stats[['ab', 'pa', 'hit', 'home_run', 'batting_avg', 'slg_percent', 'on_base_percent', 'avg_swing_speed', 'blasts_swing', 'blasts_contact']]
stats1.head()
# Out:
#                          ab   pa  hit  home_run  batting_avg  slg_percent  \
# last_name, first_name
# Guerrero Jr., Vladimir  616  697  199        30        0.323        0.544
# Ramírez, José           620  682  173        39        0.279        0.537
# Hoskins, Rhys           449  517   96        26        0.214        0.419
# Gelof, Zack             497  547  105        17        0.211        0.362
# Varsho, Daulton         459  513   98        18        0.214        0.407
#
#                         on_base_percent  avg_swing_speed  blasts_swing  \
# last_name, first_name
# Guerrero Jr., Vladimir            0.396             75.9          19.4
# Ramírez, José                     0.335             71.6          12.1
# Hoskins, Rhys                     0.303             71.2           9.1
# Gelof, Zack                       0.270             71.6           7.8
# Varsho, Daulton                   0.293             73.7           8.2
#
#                         blasts_contact
# last_name, first_name
# Guerrero Jr., Vladimir            24.2
# Ramírez, José                     13.9
# Hoskins, Rhys                     12.0
# Gelof, Zack                       12.0
# Varsho, Daulton                   11.1

# %%
stats1.corr()
# Out:
#                        ab        pa       hit  home_run  batting_avg  \
# ab               1.000000  0.946320  0.798816  0.341518     0.287826
# pa               0.946320  1.000000  0.756374  0.470357     0.273206
# hit              0.798816  0.756374  1.000000  0.399222     0.802924
# home_run         0.341518  0.470357  0.399222  1.000000     0.295960
# batting_avg      0.287826  0.273206  0.802924  0.295960     1.000000
# slg_percent      0.262149  0.367482  0.583092  0.865484     0.667860
# on_base_percent  0.131094  0.338598  0.536346  0.493695     0.728672
# avg_swing_speed  0.154493  0.230264  0.173207  0.628126     0.117393
# blasts_swing     0.219975  0.297650  0.369875  0.612132     0.373556
# blasts_contact   0.224741  0.299958  0.336172  0.665048     0.311737
#
#                  slg_percent  on_base_percent  avg_swing_speed  blasts_swing  \
# ab                  0.262149         0.131094         0.154493      0.219975
# pa                  0.367482         0.338598         0.230264      0.297650
# hit                 0.583092         0.536346         0.173207      0.369875
# home_run            0.865484         0.493695         0.628126      0.612132
# batting_avg         0.667860         0.728672         0.117393      0.373556
# slg_percent         1.000000         0.727149         0.568707      0.670465
# on_base_percent     0.727149         1.000000         0.252838      0.441306
# avg_swing_speed     0.568707         0.252838         1.000000      0.815120
# blasts_swing        0.670465         0.441306         0.815120      1.000000
# blasts_contact      0.677551         0.393981         0.878439      0.969569
#
#                  blasts_contact
# ab                     0.224741
# pa                     0.299958
# hit                    0.336172
# home_run               0.665048
# batting_avg            0.311737
# slg_percent            0.677551
# on_base_percent        0.393981
# avg_swing_speed        0.878439
# blasts_swing           0.969569
# blasts_contact         1.000000

# %%
sns.heatmap(stats1.corr(), cmap='RdYlGn', annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(stats1.corr())
